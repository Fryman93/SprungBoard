# %%
import json
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#NEW
with open('lol_data.json', 'r') as file:
   newdata = json.load(file)

# %%
#NEW
newdf = pd.DataFrame(newdata)
newdf.shape
# Out:
# (882, 13)

# %%
#NEW
newdf.head()
# Out:
#     gameCreation  gameDuration      gameId gameMode      gameType  \
# 0  1546074305758           873  2942016788     ARAM  MATCHED_GAME
# 1  1546072056795          1836  2942003298  CLASSIC  MATCHED_GAME
# 2  1546070609011          1023  2942000078  CLASSIC  MATCHED_GAME
# 3  1546063787803          2030  2941949842  CLASSIC  MATCHED_GAME
# 4  1546061423214          1930  2941921008  CLASSIC  MATCHED_GAME
#
#      gameVersion  mapId                              participantIdentities  \
# 0  8.24.255.8524     12  [{'participantId': 1, 'player': {'platformId':...
# 1  8.24.255.8524     11  [{'participantId': 1, 'player': {'platformId':...
# 2  8.24.255.8524     11  [{'participantId': 1, 'player': {'platformId':...
# 3  8.24.255.8524     11  [{'participantId': 1, 'player': {'platformId':...
# 4  8.24.255.8524     11  [{'participantId': 1, 'player': {'platformId':...
#
#                                         participants platformId  queueId  \
# 0  [{'participantId': 1, 'teamId': 100, 'champion...        NA1      450
# 1  [{'participantId': 1, 'teamId': 100, 'champion...        NA1      400
# 2  [{'participantId': 1, 'teamId': 100, 'champion...        NA1      420
# 3  [{'participantId': 1, 'teamId': 100, 'champion...        NA1      420
# 4  [{'participantId': 1, 'teamId': 100, 'champion...        NA1      420
#
#    seasonId                                              teams
# 0        11  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 1        11  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 2        11  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 3        11  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 4        11  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...

# %%
#NEW
newgames = newdf[['participants','gameMode']]
newparticipants = newdf['participants']

# We only want Summoner's Rift (Classic) 
newclassicgames = newgames[newgames['gameMode'] == 'CLASSIC']['participants']

dict((list(newclassicgames[1][4].items())[2],))
# Out:
# {'championId': 64}

# %%
t=((1,'a'),)
print(t)
dict(t)
# Out:
# ((1, 'a'),)
# {1: 'a'}

# %%
# NEW
newgames.head()
# Out:
#                                         participants gameMode
# 0  [{'participantId': 1, 'teamId': 100, 'champion...     ARAM
# 1  [{'participantId': 1, 'teamId': 100, 'champion...  CLASSIC
# 2  [{'participantId': 1, 'teamId': 100, 'champion...  CLASSIC
# 3  [{'participantId': 1, 'teamId': 100, 'champion...  CLASSIC
# 4  [{'participantId': 1, 'teamId': 100, 'champion...  CLASSIC

# %%
# Why does this run slow?

stats_keep_columns = ['participantId','win','item0','item1','item2','item3','item4','item5',
'item6','kills','deaths','assists','longestTimeSpentLiving','totalDamageDealtToChampions',
'magicDamageDealtToChampions', 'physicalDamageDealtToChampions','trueDamageDealtToChampions',
'damageDealtToTurrets','visionScore','timeCCingOthers','goldEarned','turretKills',
'perk0','perk1','perk2', 'perk3', 'perk4', 'perk5']

def create_row(row):
    '''Unpacks each list of dictionaries, from each CLASSIC game, to create a pandas row.
    Each row is organized such that the features of the winning team are displayed to the 
    left.'''
      
    a_row = []   
    for players in row:
        stats_player = pd.DataFrame.from_dict(players['stats'], orient = 'index') #Turns the dict into a pandas row
        a_row.append(stats_player.T[stats_keep_columns]) #Transposes then extracts
        champ_player = pd.DataFrame.from_dict(dict((list(players.items())[2],)), orient = 'index')
        a_row.append(champ_player.T)
        the_row = pd.concat(a_row, axis = 1)

    player_indexes = [index for index, col_name in enumerate(the_row) if col_name == 'participantId']
    if the_row.iloc[:,1].bool() == False:           
        losers = the_row.iloc[:,:player_indexes[5]]     
        the_row = pd.concat([the_row, losers], axis = 1)
        the_row = the_row.iloc[:,player_indexes[5]:]        
    the_row = the_row.drop('win',axis=1) #Drops the win columns
    return the_row 

    
newclassicwoof = newclassicgames.apply(create_row)
newclassicwoof
# Out:
# 1        participantId item0 item1 item2 item3 item4 ...
# 2        participantId item0 item1 item2 item3 item4 ...
# 3        participantId item0 item1 item2 item3 item4 ...
# 4        participantId item0 item1 item2 item3 item4 ...
# 5        participantId item0 item1 item2 item3 item4 ...
# 6        participantId item0 item1 item2 item3 item4 ...
# 7        participantId item0 item1 item2 item3 item4 ...
# 8        participantId item0 item1 item2 item3 item4 ...
# 9        participantId item0 item1 item2 item3 item4 ...
# 10       participantId item0 item1 item2 item3 item4 ...
# 11       participantId item0 item1 item2 item3 item4 ...
# 12       participantId item0 item1 item2 item3 item4 ...
# 13       participantId item0 item1 item2 item3 item4 ...
# 14       participantId item0 item1 item2 item3 item4 ...
# 15       participantId item0 item1 item2 item3 item4 ...
# 16       participantId item0 item1 item2 item3 item4 ...
# 17       participantId item0 item1 item2 item3 item4 ...
# 18       participantId item0 item1 item2 item3 item4 ...
# 19       participantId item0 item1 item2 item3 item4 ...
# 20       participantId item0 item1 item2 item3 item4 ...
# 21       participantId item0 item1 item2 item3 item4 ...
# 22       participantId item0 item1 item2 item3 item4 ...
# 23       participantId item0 item1 item2 item3 item4 ...
# 24       participantId item0 item1 item2 item3 item4 ...
# 28       participantId item0 item1 item2 item3 item4 ...
# 29       participantId item0 item1 item2 item3 item4 ...
# 30       participantId item0 item1 item2 item3 item4 ...
# 31       participantId item0 item1 item2 item3 item4 ...
# 32       participantId item0 item1 item2 item3 item4 ...
# 33       participantId item0 item1 item2 item3 item4 ...
#                              ...
# 852      participantId item0 item1 item2 item3 item4 ...
# 853      participantId item0 item1 item2 item3 item4 ...
# 854      participantId item0 item1 item2 item3 item4 ...
# 855      participantId item0 item1 item2 item3 item4 ...
# 856      participantId item0 item1 item2 item3 item4 ...
# 857      participantId item0 item1 item2 item3 item4 ...
# 858      participantId item0 item1 item2 item3 item4 ...
# 859      participantId item0 item1 item2 item3 item4 ...
# 860      participantId item0 item1 item2 item3 item4 ...
# 861      participantId item0 item1 item2 item3 item4 ...
# 862      participantId item0 item1 item2 item3 item4 ...
# 863      participantId item0 item1 item2 item3 item4 ...
# 864      participantId item0 item1 item2 item3 item4 ...
# 865      participantId item0 item1 item2 item3 item4 ...
# 866      participantId item0 item1 item2 item3 item4 ...
# 867      participantId item0 item1 item2 item3 item4 ...
# 868      participantId item0 item1 item2 item3 item4 ...
# 869      participantId item0 item1 item2 item3 item4 ...
# 870      participantId item0 item1 item2 item3 item4 ...
# 871      participantId item0 item1 item2 item3 item4 ...
# 872      participantId item0 item1 item2 item3 item4 ...
# 873      participantId item0 item1 item2 item3 item4 ...
# 874      participantId item0 item1 item2 item3 item4 ...
# 875      participantId item0 item1 item2 item3 item4 ...
# 876      participantId item0 item1 item2 item3 item4 ...
# 877      participantId item0 item1 item2 item3 item4 ...
# 878      participantId item0 item1 item2 item3 item4 ...
# 879      participantId item0 item1 item2 item3 item4 ...
# 880      participantId item0 item1 item2 item3 item4 ...
# 881      participantId item0 item1 item2 item3 item4 ...
# Name: participants, Length: 858, dtype: object

# %%
newclassicwoof[870]
# Out:
#   participantId item0 item1 item2 item3 item4 item5 item6 kills deaths  \
# 0             6  1054  3211  3153  3047  3078  1028  3340    11      0
#
#      ...     timeCCingOthers goldEarned turretKills perk0 perk1 perk2 perk3  \
# 0    ...                  22       7349           0  8437  8473  8429  8451
#
#   perk4 perk5 championId
# 0  8304  8347         54
#
# [1 rows x 280 columns]

# %%
chunks = []
for chunk in newclassicwoof:
        chunks.append(chunk)    
yes = pd.concat(chunks)

new_names = []
player_indexes = [index for index, col_name in enumerate(yes) if col_name == 'participantId']
yes = yes.drop('participantId', axis=1)

for player in range(5):
    if player != 0:
        wp = yes.iloc[:,player_indexes[player]:player_indexes[player+1]].add_prefix('WP'+str(player+1)+'_')
        new_names.append(wp)
    else:
        wp =yes.iloc[:,:player_indexes[player+1]].add_prefix('WP'+str(player+1)+'_')
        new_names.append(wp)
        
for player in range(5,10):
    if player != 9:
        lp = yes.iloc[:,player_indexes[player]:player_indexes[player+1]].add_prefix('LP'+str(player-4)+'_')
        new_names.append(lp)
    else:
        yes.iloc[:,player_indexes[player]:].add_prefix('LP'+str(player-4)+'_')

yes = pd.concat(new_names, axis=1)
yes.reset_index(drop=True)
# Out:
#     WP1_item0 WP1_item1 WP1_item2 WP1_item3 WP1_item4 WP1_item5 WP1_item6  \
# 0        3040      3020      3285      1056      3135         0      3363
# 1        2003         0      1052      1001      3285      1056      3340
# 2        2031      3143      3050      3401      3047      2055      3364
# 3        3020      3146      3157      3113         0         0      3340
# 4        3222      3107      3098      3041      3504      3111      3363
# 5        2033      3077      3078      3111      3052         0      3340
# 6        2033      3057      3113      3041      3020      3027      3340
# 7        1416      2031      3111      3146      1028         0      3340
# 8        3157      3100      3102      3020      3285      1058      3364
# 9        3077      3071      2031      3111      3742      1036      3340
# 10       1054      3158      3748      3068      3067      1028      3340
# 11       1412         0      3078      3047      1031      2031      3340
# 12       3098      2031      1058      3285      3020      1058      3364
# 13       1054      3157      3047      3146      3916      3068      3340
# 14       1412      2055      3071      1011      3111      1029      3364
# 15       3117      3078      1413      1028      1036         0      3340
# 16       1082      3157      3113      3135      3151      3020      3340
# 17       3117      2031      1413      3078      3742         0      3340
# 18       3047      3071      1038      3153      1037      3094      3340
# 19       3157      3095      3006      3124      3086         0      3363
# 20       1412      3071      3077      3052      3147      3117      3340
# 27       3117      3136      1026         0      3340         8         11
# 28       3020      1026      3092         0      3364         1          7
# 29       3022      1011      1031      2422      3340         2         12
# ..        ...       ...       ...       ...       ...       ...        ...
# 828      3026      3031      3046         0      3340         2          6
# 829      3006      3133      1018         0      3340         0          3
# 830         0      3047      1036         0      3340         3          3
# 831      3087      3006      3072      1038      3363        11          7
# 832      3006      3046      1053         0      3340         6          9
# 833      3047      2003         0         0      3340         3          5
# 834      3115      1082         0      3020      3363         4          3
# 835      3047      1031      1057      1011      3364         1          8
# 836      3814      3117      3147         0      3363         8          6
# 837      3031      3111      3046         0      3340         7         10
# 838      3107      3047         0         0      3364         0          5
# 839      3047      3211      3067         0      3340         5          4
# 840      3047      3124      1419      3085      3364         9         10
# 841      3134      3133      1036      3142      3340         2          8
# 842      3085      1055      3087      1053      3340         9          7
# 843      3748      3071      1036         0      3340         5          6
# 844      1402      3151      3067      3801      3340        10          5
# 845      3094      3031      3047      3085      3363        12          8
# 846      3047      3751      1031      1028      3340         3          5
# 847      1056      3057      3111      3113      3340         2          3
# 848      3052      2033      1028         0      3340         5          5
# 849      2033      2055      3285      1056      3363         6          4
# 850      3124      3006      3085      1038      3363        11          6
# 851      3165      3020      3135         0      3340         6          8
# 852      3006      3046      1038      1037      3363         9          7
# 853      3748      3047      3078         0      3340         3          5
# 854      3057      1052      1026         0      3340         3          5
# 855      3109      3158      3211         0      3364         3         11
# 856      3031      1042         0         0      3340         3          8
# 857      3157      3027      3020      1058      3340         2          3
#
# [858 rows x 243 columns]

# %%
chunks = []
for chunk in newclassicwoof:
    chunks.append(chunk)    
yes = pd.concat(chunks)

player_indexes = [index for index, col_name in enumerate(yes) if col_name == 'participantId']
yes = yes.drop('participantId', axis=1)

wp_1 = yes.iloc[:,:player_indexes[1]].add_prefix('WP1_')
wp_2 = yes.iloc[:,player_indexes[1]:player_indexes[2]].add_prefix('WP2_')
wp_3 = yes.iloc[:,player_indexes[2]:player_indexes[3]].add_prefix('WP3_')
wp_4 = yes.iloc[:,player_indexes[3]:player_indexes[4]].add_prefix('WP4_')
wp_5 = yes.iloc[:,player_indexes[4]:player_indexes[5]].add_prefix('WP5_')

lp_1 = yes.iloc[:,player_indexes[5]:player_indexes[6]].add_prefix('LP1_')
lp_2 = yes.iloc[:,player_indexes[6]:player_indexes[7]].add_prefix('LP2_')
lp_3 = yes.iloc[:,player_indexes[7]:player_indexes[8]].add_prefix('LP3_')
lp_4 = yes.iloc[:,player_indexes[8]:player_indexes[9]].add_prefix('LP4_')
lp_5 = yes.iloc[:,player_indexes[9]:].add_prefix('LP5_')

new_names = [wp_1, wp_2, wp_3, wp_4, wp_5, lp_1, lp_2, lp_3, lp_4, lp_5]
yes = pd.concat(new_names, axis=1)
yes.reset_index(drop=True)
# Out:
#     WP1_item0 WP1_item1 WP1_item2 WP1_item3 WP1_item4 WP1_item5 WP1_item6  \
# 0        3040      3020      3285      1056      3135         0      3363
# 1        2003         0      1052      1001      3285      1056      3340
# 855      8304      8347            412
# 856      8126      8136             18
# 857      8304      8321             34
#
# [858 rows x 270 columns]

# %%
#TEAM DATA

agg = ['kills', 'deaths', 'assists', 'physicalDamageDealtToChampions', 'magicDamageDealtToChampions',
       'trueDamageDealtToChampions','totalDamageDealtToChampions', 'timeCCingOthers', 'visionScore',
       'longestTimeSpentLiving', 'goldEarned', 'damageDealtToTurrets']

team = pd.DataFrame()

for feature in agg: 
    team['Win_'+ feature] = yes[[col for col in yes.columns if 'WP' in col and feature in col]].sum(axis=1)
    team['Lose_'+ feature] = yes[[col for col in yes.columns if 'LP' in col and feature in col]].sum(axis=1)
team.reset_index(drop=True)

# %%
sns.boxplot(data=team[['Win_goldEarned','Lose_goldEarned']]);

# %%
sns.boxplot(data=team[['Win_longestTimeSpentLiving','Lose_longestTimeSpentLiving']]);

# %%
sns.boxplot(data=team[['Win_kills','Lose_kills']]);

# %%
sns.boxplot(data=team[['Win_visionScore','Lose_visionScore']]);

# %%
sns.boxplot(data=team[['Win_timeCCingOthers','Lose_timeCCingOthers']]);

# %%
sns.boxplot(data=team[['Win_physicalDamageDealtToChampions','Lose_physicalDamageDealtToChampions']]);

# %%
sns.boxplot(data=team[['Win_magicDamageDealtToChampions','Lose_magicDamageDealtToChampions']]);

# %%
sns.boxplot(data=team[['Win_trueDamageDealtToChampions','Lose_trueDamageDealtToChampions']]);

# %%
sns.boxplot(data=team[['Win_goldEarned','Lose_goldEarned']]);

# %%
sns.boxplot(data=team[['Win_totalDamageDealtToChampions','Lose_totalDamageDealtToChampions']]);

# %%
sns.boxplot(data=team[['Win_damageDealtToTurrets','Lose_damageDealtToTurrets']]);

# %%
winners = team[[col for col in team.columns if 'Win' in col]]

plt.figure(figsize=(10, 7))
sns.heatmap(winners.corr(), annot=True, cmap='Blues');

# %%
losers = team[[col for col in team.columns if 'Lose' in col]]

plt.figure(figsize=(10, 7))
sns.heatmap(losers.corr(), annot=True, cmap='Oranges');

# %%
plt.hist(team['Win_damageDealtToTurrets'],bins=50, normed=True);

# %%
# Extracting games that include one or more turret hard hitters 

url_champ = 'http://ddragon.leagueoflegends.com/cdn/8.24.1/data/en_US/champion.json'
champion_info = requests.get(url_champ).json()

url_rune = 'http://ddragon.leagueoflegends.com/cdn/8.24.1/data/en_US/runesReforged.json'
rune_info = requests.get(url_rune).json()

champion_info

# %%
champion_info['data']

# %%
# key_to_champ: Dictionary with the championID as keys and champion name as values  

champ_list = list(champion_info['data'].keys())

champ_keys = []
for champ in champ_list:
    key = champion_info['data'][champ]['key']
    champ_keys.append(int(key))
champ_keys

key_to_champ = dict(zip(champ_keys, champ_list))

list(key_to_champ.items())[:10] #The 'head' of the dictionary

# %%
key_to_champ[143]

# %%
# key_to_rune: Dictionary with the RuneID as keys and rune name as values

key_to_rune = {}

for rune_path in rune_info:
    for rune_line in rune_path['slots']:
        for rune in rune_line['runes']:
            key_to_rune[rune['id']] = rune['key']
            
list(key_to_rune.items())[:10] #The 'head' of the dictionary
